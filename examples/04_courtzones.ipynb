# %%
from datavolley import read_dv
import datavolley.pycourtZones as pycourt
import pandas as pd
from shapely.geometry import Point, Polygon
import matplotlib.pyplot as plt

# %%
dvf = read_dv.DataVolley()
plays = dvf.get_plays()
# Out:
# /Users/acco/Desktop/src/pydatavolley/datavolley/helpers.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned.loc[:, col] = pd.to_numeric(df_cleaned[col], errors='coerce').astype('Int64')

# %%
# Crea una griglia di subplot con una riga e due colonne
fig, axs = plt.subplots(1, 2, figsize=(10, 5))

#Chiamata squadra 1

subset_plays = plays.loc[plays['team'] == 'University of Dayton']

coordinate_pairs = [(x, y) for x, y in zip(subset_plays['end_coordinate_x'], subset_plays['end_coordinate_y']) if pd.notna(x) and pd.notna(y)]
pycourt.pycourtZones(coordinate_pairs, ax=axs[0])



axs[0].set_title('University of Dayton')  # Aggiungi un titolo al subplot
axs[0].set_xticks([])  
axs[0].set_yticks([])  

#Chiamata squadra 2

subset_plays = plays.loc[plays['team'] == 'University of Louisville']

coordinate_pairs = [(x, y) for x, y in zip(subset_plays['end_coordinate_x'], subset_plays['end_coordinate_y']) if pd.notna(x) and pd.notna(y)]
pycourt.pycourtZones(coordinate_pairs, ax=axs[1], invert_y=True)

axs[1].set_title('University of Louisville')  # Aggiungi un titolo al subplot
axs[1].set_xticks([])  
axs[1].set_yticks([]) 


 # Aggiunge spaziatura tra i subplot per evitare sovrapposizioni
plt.show()
# Out:
# Quadrato 1: 0 punti
# Quadrato 2: 0 punti
# Quadrato 3: 0 punti
# Quadrato 4: 0 punti
# Quadrato 5: 0 punti
# Quadrato 6: 0 punti
# Quadrato 7: 4 punti
# Quadrato 8: 5 punti
# Quadrato 9: 0 punti
# Quadrato 10: 9 punti
# Quadrato 11: 10 punti
# Quadrato 12: 8 punti
# Quadrato 13: 40 punti
# Quadrato 14: 45 punti
# Quadrato 15: 44 punti
# Quadrato 16: 25 punti
# Quadrato 17: 56 punti
# Quadrato 18: 32 punti
# Quadrato 1: 0 punti
# Quadrato 2: 0 punti
# Quadrato 3: 0 punti
# Quadrato 4: 0 punti
# Quadrato 5: 0 punti
# Quadrato 6: 0 punti
# Quadrato 7: 2 punti
# Quadrato 8: 2 punti
# Quadrato 9: 1 punti
# Quadrato 10: 10 punti
# Quadrato 11: 8 punti
# Quadrato 12: 11 punti
# Quadrato 13: 45 punti
# Quadrato 14: 45 punti
# Quadrato 15: 50 punti
# Quadrato 16: 26 punti
# Quadrato 17: 53 punti
# Quadrato 18: 36 punti

# %%
# Crea una griglia di subplot con una riga e due colonne
fig, axs = plt.subplots(1, 2, figsize=(10, 5))

#Chiamata squadra 1

subset_plays = plays.loc[plays['team'] == 'University of Dayton']

coordinate_pairs = [(x, y) for x, y in zip(subset_plays['end_coordinate_x'], subset_plays['end_coordinate_y']) if pd.notna(x) and pd.notna(y)]
pycourt.pycourtSubZones(coordinate_pairs, ax=axs[0])



axs[0].set_title('University of Dayton')  # Aggiungi un titolo al subplot
axs[0].set_xticks([])  
axs[0].set_yticks([])  

#Chiamata squadra 2

subset_plays = plays.loc[plays['team'] == 'University of Louisville']

coordinate_pairs = [(x, y) for x, y in zip(subset_plays['end_coordinate_x'], subset_plays['end_coordinate_y']) if pd.notna(x) and pd.notna(y)]
pycourt.pycourtSubZones(coordinate_pairs, ax=axs[1], invert_y=True)

axs[1].set_title('University of Louisville')  # Aggiungi un titolo al subplot
axs[1].set_xticks([])  
axs[1].set_yticks([]) 


 # Aggiunge spaziatura tra i subplot per evitare sovrapposizioni
plt.show()
